# %%
import pandas as pd

# %%
data = pd.read_csv("Medidas todos os ovos.csv")
data
# Out:
#        N_OVO  P_OVO  AL_ALB  PH_ALB    P_GE  C_GE    YH    YD     YI    HU  \
# 0       ovo1   59.9     6.9     8.1  14.401   6.0  13.4  39.7  0.338  83.1
# 1       ovo2   67.2     9.0     8.4  17.197   6.0  18.5  46.0  0.402  93.1
# 2       ovo3   67.8     8.3     8.1  16.137   5.0  17.6  39.7  0.443  89.3
# 3       ovo4   59.0     8.5     8.0  16.182   5.0  16.5  43.0  0.384  92.5
# 4       ovo5   65.5     6.8     8.8  15.553   6.0  16.8  41.0  0.410  80.7
# ..       ...    ...     ...     ...     ...   ...   ...   ...    ...   ...
# 891   ovo996   63.4     3.0    10.6  16.836   6.0  12.0  46.3  0.259  43.3
# 892   ovo997   55.9     3.6    10.7  14.763   5.0  10.6  45.0  0.236  56.4
# 893   ovo998   59.9     2.9    10.5  17.815   6.0  13.5  46.0  0.293  44.3
# 894   ovo999   57.8     4.1    10.5  18.117   6.0  14.1  44.7  0.315  61.0
# 895  ovo1000   68.6     3.6    10.5  19.124   7.0  14.4  45.3  0.318  48.8
#
# ...

# %%
data.loc[:596, 'N_OVO'] = data.loc[:596, 'N_OVO'].apply(lambda x: 'imagens/train/' + x + '.png')
train_data = data.loc[:596]

train_data.to_csv("train.csv", index=False)
train_data
# Out:
#                         N_OVO  P_OVO  AL_ALB  PH_ALB    P_GE  C_GE    YH  \
# 0      imagens/train/ovo1.png   59.9     6.9     8.1  14.401   6.0  13.4
# 1      imagens/train/ovo2.png   67.2     9.0     8.4  17.197   6.0  18.5
# 2      imagens/train/ovo3.png   67.8     8.3     8.1  16.137   5.0  17.6
# 3      imagens/train/ovo4.png   59.0     8.5     8.0  16.182   5.0  16.5
# 4      imagens/train/ovo5.png   65.5     6.8     8.8  15.553   6.0  16.8
# ..                        ...    ...     ...     ...     ...   ...   ...
# 592  imagens/train/ovo636.png   61.1     4.3    10.0  19.610   7.0  12.0
# 593  imagens/train/ovo637.png   63.5     3.4    10.3  18.632   6.0  10.4
# 594  imagens/train/ovo638.png   62.9     3.1    10.2  19.153   6.0  11.0
# 595  imagens/train/ovo639.png   63.3     3.3    10.1  19.627   7.0  10.8
# 596  imagens/train/ovo640.png   71.9     3.0    10.4  22.506   6.0  11.9
#
#        YD     YI    HU  ...     D4  TEMPO  CL_PESO_Extra  CL_PESO_Grande  \
# ...

# %%
data.loc[597:, 'N_OVO'] = data.loc[597:, 'N_OVO'].apply(lambda x: 'imagens/test/' + x + '.png')
test_data = data.loc[597:]

test_data.to_csv("test.csv", index=False)
test_data
# Out:
#                         N_OVO  P_OVO  AL_ALB  PH_ALB    P_GE  C_GE    YH  \
# 597   imagens/test/ovo641.png   67.8     3.5    10.7  20.387   7.0  10.3
# 598   imagens/test/ovo642.png   58.3     3.6    10.2  17.853   6.0  12.8
# 599   imagens/test/ovo643.png   75.3     4.3    10.1  20.487   6.0  13.5
# 600   imagens/test/ovo646.png   64.2     3.5    10.3  17.971   6.0  13.6
# 601   imagens/test/ovo647.png   62.2     4.1     9.9  18.497   6.0  14.4
# ..                        ...    ...     ...     ...     ...   ...   ...
# 891   imagens/test/ovo996.png   63.4     3.0    10.6  16.836   6.0  12.0
# 892   imagens/test/ovo997.png   55.9     3.6    10.7  14.763   5.0  10.6
# 893   imagens/test/ovo998.png   59.9     2.9    10.5  17.815   6.0  13.5
# 894   imagens/test/ovo999.png   57.8     4.1    10.5  18.117   6.0  14.1
# 895  imagens/test/ovo1000.png   68.6     3.6    10.5  19.124   7.0  14.4
#
#        YD     YI    HU  ...     D4  TEMPO  CL_PESO_Extra  CL_PESO_Grande  \
# ...
